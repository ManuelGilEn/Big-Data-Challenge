# %%
# importamos librería pandas
import pandas as pd
# leemos el dataset y lo guardamos en una variable
myData=pd.read_csv("DataSet_Final_equipo7_10kChallenge.csv")
myData.head()
# Out:
#      Entidad Federativa  Unidades económicas  \
# 0        Aguascalientes                61645
# 1       Baja California               125975
# 2   Baja California Sur                35745
# 3              Campeche                41612
# 4  Coahuila de Zaragoza               114465
#
#    Precipitación media histórica (mm)  Abastecimiento diario de agua  \
# 0                                 480                         300040
# 1                                 196                         868940
# 2                                 182                          87106
# 3                                1209                         161795
# 4                                 338                         574704
#
#    PorcentajeSequia  Normal  Moderada  severa  extrema  excepcional
# 0             100.0    25.1      54.0    20.9      0.0          0.0
# 1              99.7     0.0       6.4    77.2     16.1          0.0
# 2              84.7    33.2      33.7    15.3      2.5          0.0
# ...

# %%
#obtuvimos la media, desviación estandar y quartiles de los datos
myData.describe()
# Out:
#        Unidades económicas  Precipitación media histórica (mm)  \
# count            32.000000                           32.000000
# mean         172771.812500                          889.656250
# std          144563.960677                          483.910323
# min           35745.000000                          182.000000
# 25%           79199.000000                          554.750000
# 50%          124788.000000                          800.500000
# 75%          226830.500000                         1109.250000
# max          700406.000000                         2385.000000
#
#        Abastecimiento diario de agua  PorcentajeSequia     Normal   Moderada  \
# count                   3.200000e+01         32.000000  32.000000  32.000000
# mean                    6.638588e+05         63.690625  27.987500  18.284375
# std                     5.762354e+05         35.102820  18.997364  18.326556
# min                     8.710600e+04          4.100000   0.000000   0.000000
# ...

# %%
#gráficamos el mapa de calor
corr=myData.corr()
import seaborn as sns
sns.heatmap(corr)
print(corr)
# Out:
#                                     Unidades económicas  \
# Unidades económicas                            1.000000
# Precipitación media histórica (mm)             0.120421
# Abastecimiento diario de agua                  0.832731
# PorcentajeSequia                              -0.163122
# Normal                                         0.167345
# Moderada                                      -0.191483
# severa                                        -0.193183
# extrema                                       -0.142523
# excepcional                                   -0.093176
#
#                                     Precipitación media histórica (mm)  \
# Unidades económicas                                           0.120421
# Precipitación media histórica (mm)                            1.000000
# Abastecimiento diario de agua                                -0.082365
# PorcentajeSequia                                             -0.747715
# ...

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
scatter_matrix(myData)
plt.show()

# %%
#Histograma
myData.PorcentajeSequia.plot(kind="hist")
plt.show()

# %%
#varianza
myData.var()
# Out:
# C:\Users\irmag\AppData\Local\Temp\ipykernel_22172\2745623232.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   myData.var()
# Unidades económicas                   2.089874e+10
# Precipitación media histórica (mm)    2.341692e+05
# Abastecimiento diario de agua         3.320473e+11
# PorcentajeSequia                      1.232208e+03
# Normal                                3.608998e+02
# Moderada                              3.358627e+02
# severa                                4.018837e+02
# extrema                               4.374387e+01
# excepcional                           2.713861e+00
# dtype: float64

# %%
#simetría
myData.skew
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.skew of                  Entidad Federativa  Unidades económicas  \
# 0                    Aguascalientes                61645
# 1                   Baja California               125975
# 2               Baja California Sur                35745
# 3                          Campeche                41612
# 4              Coahuila de Zaragoza               114465
# 5                            Colima                38511
# 6                           Chiapas               218824
# 7                         Chihuahua               128139
# 8                  Ciudad de México               474306
# 9                           Durango                66735
# 10                       Guanajuato               272543
# 11                         Guerrero               169783
# 12                          Hidalgo               139255
# 13                          Jalisco               378068
# ...

# %%
#kurtosis
myData.kurtosis()
# Out:
# C:\Users\irmag\AppData\Local\Temp\ipykernel_22172\4148539892.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   myData.kurtosis()
# Unidades económicas                    4.845507
# Precipitación media histórica (mm)     2.068063
# Abastecimiento diario de agua          1.672023
# PorcentajeSequia                      -1.515754
# Normal                                -0.524835
# Moderada                              -0.565271
# severa                                 3.271501
# extrema                                7.550772
# excepcional                           18.149393
# dtype: float64
